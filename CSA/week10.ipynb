# %%
import pandas as pd 

df = pd.read_excel("provinces.xlsx")
df
# Out:
#                  Name              Division  ...    Area  Population
# 0    Thành phố Hà Nội  Thành phố Trung ương  ...  3358.6      8093.9
# 1       Tỉnh Hà Giang                  Tỉnh  ...  7929.5       858.1
# 2       Tỉnh Cao Bằng                  Tỉnh  ...  6700.3       530.9
# 3        Tỉnh Bắc Kạn                  Tỉnh  ...  4860.0       314.4
# 4    Tỉnh Tuyên Quang                  Tỉnh  ...  5867.9       786.3
# ..                ...                   ...  ...     ...         ...
# 58  Thành phố Cần Thơ  Thành phố Trung ương  ...  1439.0      1236.0
# 59     Tỉnh Hậu Giang                  Tỉnh  ...  1621.7       732.2
# 60     Tỉnh Sóc Trăng                  Tỉnh  ...  3311.9      1199.5
# 61      Tỉnh Bạc Liêu                  Tỉnh  ...  2669.0       908.2
# 62        Tỉnh Cà Mau                  Tỉnh  ...  5221.2      1194.3
#
# [63 rows x 5 columns]

# %%
df.loc[0, "Name"] = "Thủ Đô Hà Nội"
df.loc[0, "Region"] = "Đồng Bằng Sông Hồng"
df.loc[1, "Division"] = "Thành phố Trung ương"
df
# Out:
#                  Name              Division  ...    Area  Population
# 0       Thủ Đô Hà Nội  Thành phố Trung ương  ...  3358.6      8093.9
# 1       Tỉnh Hà Giang  Thành phố Trung ương  ...  7929.5       858.1
# 2       Tỉnh Cao Bằng                  Tỉnh  ...  6700.3       530.9
# 3        Tỉnh Bắc Kạn                  Tỉnh  ...  4860.0       314.4
# 4    Tỉnh Tuyên Quang                  Tỉnh  ...  5867.9       786.3
# ..                ...                   ...  ...     ...         ...
# 58  Thành phố Cần Thơ  Thành phố Trung ương  ...  1439.0      1236.0
# 59     Tỉnh Hậu Giang                  Tỉnh  ...  1621.7       732.2
# 60     Tỉnh Sóc Trăng                  Tỉnh  ...  3311.9      1199.5
# 61      Tỉnh Bạc Liêu                  Tỉnh  ...  2669.0       908.2
# 62        Tỉnh Cà Mau                  Tỉnh  ...  5221.2      1194.3
#
# [63 rows x 5 columns]

# %%
df2 = df.replace("Tỉnh", "TỈNH", inplace = False)
df2
# Out:
#                  Name              Division  ...    Area  Population
# 0       Thủ Đô Hà Nội  Thành phố Trung ương  ...  3358.6      8093.9
# 1       Tỉnh Hà Giang  Thành phố Trung ương  ...  7929.5       858.1
# 2       Tỉnh Cao Bằng                  TỈNH  ...  6700.3       530.9
# 3        Tỉnh Bắc Kạn                  TỈNH  ...  4860.0       314.4
# 4    Tỉnh Tuyên Quang                  TỈNH  ...  5867.9       786.3
# ..                ...                   ...  ...     ...         ...
# 58  Thành phố Cần Thơ  Thành phố Trung ương  ...  1439.0      1236.0
# 59     Tỉnh Hậu Giang                  TỈNH  ...  1621.7       732.2
# 60     Tỉnh Sóc Trăng                  TỈNH  ...  3311.9      1199.5
# 61      Tỉnh Bạc Liêu                  TỈNH  ...  2669.0       908.2
# 62        Tỉnh Cà Mau                  TỈNH  ...  5221.2      1194.3
#
# [63 rows x 5 columns]

# %%
df["Rank"] = ["NaN"] * 63
df
# Out:
#                  Name              Division  ... Population  Rank
# 0       Thủ Đô Hà Nội  Thành phố Trung ương  ...     8093.9   NaN
# 1       Tỉnh Hà Giang  Thành phố Trung ương  ...      858.1   NaN
# 2       Tỉnh Cao Bằng                  Tỉnh  ...      530.9   NaN
# 3        Tỉnh Bắc Kạn                  Tỉnh  ...      314.4   NaN
# 4    Tỉnh Tuyên Quang                  Tỉnh  ...      786.3   NaN
# ..                ...                   ...  ...        ...   ...
# 58  Thành phố Cần Thơ  Thành phố Trung ương  ...     1236.0   NaN
# 59     Tỉnh Hậu Giang                  Tỉnh  ...      732.2   NaN
# 60     Tỉnh Sóc Trăng                  Tỉnh  ...     1199.5   NaN
# 61      Tỉnh Bạc Liêu                  Tỉnh  ...      908.2   NaN
# 62        Tỉnh Cà Mau                  Tỉnh  ...     1194.3   NaN
#
# [63 rows x 6 columns]

# %%
lst = []
for i in range(len(df)):
    popu = df.loc[i, "Population"] * 1000
    area = df.loc[i, "Area"]
    x = popu / area
    lst.append(x)
    
df["PopulationDensity"] = lst
df
# Out:
#                  Name              Division  ... Rank  PopulationDensity
# 0       Thủ Đô Hà Nội  Thành phố Trung ương  ...  NaN        2409.902936
# 1       Tỉnh Hà Giang  Thành phố Trung ương  ...  NaN         108.216155
# 2       Tỉnh Cao Bằng                  Tỉnh  ...  NaN          79.235258
# 3        Tỉnh Bắc Kạn                  Tỉnh  ...  NaN          64.691358
# 4    Tỉnh Tuyên Quang                  Tỉnh  ...  NaN         134.000239
# ..                ...                   ...  ...  ...                ...
# 58  Thành phố Cần Thơ  Thành phố Trung ương  ...  NaN         858.929812
# 59     Tỉnh Hậu Giang                  Tỉnh  ...  NaN         451.501511
# 60     Tỉnh Sóc Trăng                  Tỉnh  ...  NaN         362.178810
# 61      Tỉnh Bạc Liêu                  Tỉnh  ...  NaN         340.277257
# 62        Tỉnh Cà Mau                  Tỉnh  ...  NaN         228.740519
#
# [63 rows x 7 columns]

# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 1.4 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1

# %%
# Số lượng tỉnh thành giáp biển ở Việt Nam
df1 = pd.read_excel("coastlines.xls")
print(f"Có {len(df1)} tỉnh thành giáp biển")
# Out:
# Có 28 tỉnh thành giáp biển

# %%
# Cập nhật dữ liệu đường bờ biển vào df 

lst_coastline = [0] * 63
df["Coastline"] = lst_coastline

for i in range(len(df1)):
    name = df1.loc[i, "Name"]
    coastline = df1.loc[i, "Coastline"]
    
    df.loc[df["Name"] == name, "Coastline"] = coastline
    
print(df)
# Out:
#                  Name              Division  ... PopulationDensity  Coastline
# 0       Thủ Đô Hà Nội  Thành phố Trung ương  ...       2409.902936          0
# 1       Tỉnh Hà Giang  Thành phố Trung ương  ...        108.216155          0
# 2       Tỉnh Cao Bằng                  Tỉnh  ...         79.235258          0
# 3        Tỉnh Bắc Kạn                  Tỉnh  ...         64.691358          0
# 4    Tỉnh Tuyên Quang                  Tỉnh  ...        134.000239          0
# ..                ...                   ...  ...               ...        ...
# 58  Thành phố Cần Thơ  Thành phố Trung ương  ...        858.929812          0
# 59     Tỉnh Hậu Giang                  Tỉnh  ...        451.501511          0
# 60     Tỉnh Sóc Trăng                  Tỉnh  ...        362.178810         72
# 61      Tỉnh Bạc Liêu                  Tỉnh  ...        340.277257         56
# 62        Tỉnh Cà Mau                  Tỉnh  ...        228.740519        254
#
# [63 rows x 8 columns]

# %%
# xuất dữ liệu vào file provinces_updated.xls
df.to_excel("provinces_updated.xlsx")
print("Ghi file thành công!")
# Out:
# Ghi file thành công!

# %%
# Out:
# Collecting xlwt
#   Downloading xlwt-1.3.0-py2.py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: xlwt
# Successfully installed xlwt-1.3.0

# %%
# Đọc file borders với từng sheet bằng sheet_name
df2 = pd.read_excel("borders.xls", sheet_name="CHN")
df2
# Out:
#      Tên tỉnh  ... Đường biên (km)
# 0   Điện Biên  ...              40
# 1    Lai Châu  ...             273
# 2     Lào Cai  ...             203
# 3    Hà Giang  ...             272
# 4    Cao Bằng  ...             333
# 5    Lạng Sơn  ...             253
# 6  Quảng Ninh  ...             118
#
# [7 rows x 3 columns]

# %%
# initilize empty result DataFrame
df = pd.DataFrame(columns=['Name', 'BorderWith', 'BorderCount'])

# loop over countries, corresponding to each datasheet
for country in (('CHN', 'China'), ('LAO', 'Laos'), ('KHM', 'Cambodia')):
    
    # read data from a sheet
    inp_df = pd.read_excel('borders.xls', sheet_name=country[0])

    # loop over provinces in `inp_df`
    for name in inp_df['Tên tỉnh']:
        matching_row = df[df['Name'] == name]  # find matching row in `df`
        if len(matching_row) == 0:  # matching row not found => append new province to `df`
            df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
        else:                       # matching row found => update the row in `df`
            df.at[matching_row.index[0], 'BorderWith'] += ', ' + country[1]
            df.at[matching_row.index[0], 'BorderCount'] += 1

# save resulting DataFrame to file
df.to_excel('borders_updated.xls', index=False)
df
# Out:
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'BorderWith': country[1], 'BorderCount': 1}, ignore_index=True)
# /var/folders/hc/4s_sjqy12fzb96l95nmlcwv00000gn/T/ipykernel_32479/4166388632.py:20: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('borders_updated.xls', index=False)
#               Name      BorderWith BorderCount
# 0        Điện Biên     China, Laos           2
# 1         Lai Châu           China           1
# 2          Lào Cai           China           1
# 3         Hà Giang           China           1
# 4         Cao Bằng           China           1
# 5         Lạng Sơn           China           1
# 6       Quảng Ninh           China           1
# 7           Sơn La            Laos           1
# 8        Thanh Hóa            Laos           1
# 9          Nghệ An            Laos           1
# 10         Hà Tĩnh            Laos           1
# 11      Quảng Bình            Laos           1
# 12       Quảng Trị            Laos           1
# 13  Thừa Thiên Huế            Laos           1
# 14       Quảng Nam            Laos           1
# 15         Kon Tum  Laos, Cambodia           2
# 16         Gia Lai        Cambodia           1
# 17         Đắk Lắk        Cambodia           1
# 18        Đắk Nông        Cambodia           1
# 19      Bình Phước        Cambodia           1
# 20        Tây Ninh        Cambodia           1
# 21         Long An        Cambodia           1
# 22       Đồng Tháp        Cambodia           1
# 23        An Giang        Cambodia           1
# 24      Kiên Giang        Cambodia           1
