# %%
import pandas as pd

# %%
import pandas as pd

data = pd.read_csv('D:\Programming\Tri tue nhan tao\Tu luyen tap\HousePrice.csv')
print(data)
# Out:
#    area   price
# 0  2700  560000
# 1  2800  570000
# 2  3000  600000
# 3  3100  610000
# 4  3200  635000
# 5  3400  700000
# 6  3500  730000
# 7  3700  800000
# 8  3800  812000
# 9  4100  901000

# %%
print(data['area'])
# Out:
# 0    2700
# 1    2800
# 2    3000
# 3    3100
# 4    3200
# 5    3400
# 6    3500
# 7    3700
# 8    3800
# 9    4100
# Name: area, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.scatter(data['area'], data['price'])
plt.show()
